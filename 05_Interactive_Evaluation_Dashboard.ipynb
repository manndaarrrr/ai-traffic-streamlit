# %%
# %run "./04_evaluation_and_plots.py"
# Out:
# Working directory: C:\Users\manda\OneDrive\Documents\AI Traffic - Jupyter
# Network exists?  True
# Routes exist?   True
# Config exists?  True
# Weights exist?  True
# SUMO_HOME: C:\Program Files (x86)\Eclipse\Sumo\
# Total TLS: 7
# ('1234828897', '1757353212', '1757353214', '1783045940', '1783045985', '1843356909', '7671039164')
#
# TLS → lanes:
# 1234828897 : ['107445428#1_0', '-173540663#0_0', '-47195458#0_0']
# 1757353212 : ['1173473098#2_0', '107445426#1_0', '173540663#2_0']
# 1757353214 : ['800859756#1_0', '800859756#1_1']
# 1783045940 : ['-821520600#3_0', '315129223#3_0', '315129223#3_1', '821520600#2_0']
# 1783045985 : ['-821520600#2_0', '821520600#1_0', '324489280#3_0']
# 1843356909 : ['223051913#1_0', '223051913#1_1']
# 7671039164 : ['164073716#1_0', '164073716#1_1', '164073716#1_2']
# State lengths per TLS: [7, 7, 5, 9, 7, 5, 7]
# feature_size: 9
# num_nodes: 7
#
# Adjacency list:
# 1234828897 : []
# 1757353212 : []
# 1757353214 : []
# 1783045940 : ['1783045985']
# ...

# %%
fixed_metrics = run_episode_with_metrics("fixed", max_steps=3600)
ai_metrics    = run_episode_with_metrics("ai",    max_steps=3600)

fixed_metrics.keys(), ai_metrics.keys()
# Out:
# [FIXED+METRICS] Step 600/3600, reward=-0.0000, wait=0.0, queue=0
# [FIXED+METRICS] Step 1200/3600, reward=-0.0270, wait=27.0, queue=1
# [FIXED+METRICS] Step 1800/3600, reward=-0.0040, wait=4.0, queue=1
# [FIXED+METRICS] Step 2400/3600, reward=-0.0000, wait=0.0, queue=0
# [FIXED+METRICS] Step 3000/3600, reward=-0.0310, wait=31.0, queue=1
# [FIXED+METRICS] Step 3600/3600, reward=-0.0010, wait=1.0, queue=1
# [FIXED+METRICS] Episode finished. Total return: -107.5660000000005
# [AI+METRICS] Step 600/3600, reward=-0.0150, wait=15.0, queue=1
# [AI+METRICS] Step 1200/3600, reward=-0.0070, wait=7.0, queue=2
# [AI+METRICS] Step 1800/3600, reward=-0.0010, wait=1.0, queue=1
# [AI+METRICS] Step 2400/3600, reward=-0.0050, wait=5.0, queue=3
# [AI+METRICS] Step 3000/3600, reward=-0.0000, wait=0.0, queue=0
# [AI+METRICS] Step 3600/3600, reward=-0.0050, wait=5.0, queue=1
# [AI+METRICS] Episode finished. Total return: -24.461000000000077
# ...
